# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
file_path = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust/2:8:24/Data_HIRE4573_1722639792113 - Test Site.xlsx'
df = pd.read_excel(file_path, sheet_name='Data_HIRE4573_1722639792113', engine='openpyxl')

# Calculate max PM values
max_pm10 = df['PM10 particles (ug/m^3)'].max()
max_pm25 = df['PM2.5 particles (ug/m^3)'].max()
max_pm1 = df['PM1 particles (ug/m^3)'].max()

# Calculate average PM values
avg_pm10 = df['PM10 particles (ug/m^3)'].mean()
avg_pm25 = df['PM2.5 particles (ug/m^3)'].mean()
avg_pm1 = df['PM1 particles (ug/m^3)'].mean()

# Calculate L90, L50, and L10 for PM values
L90_pm10 = df['PM10 particles (ug/m^3)'].quantile(0.90)
L50_pm10 = df['PM10 particles (ug/m^3)'].quantile(0.50)
L10_pm10 = df['PM10 particles (ug/m^3)'].quantile(0.10)

L90_pm25 = df['PM2.5 particles (ug/m^3)'].quantile(0.90)
L50_pm25 = df['PM2.5 particles (ug/m^3)'].quantile(0.50)
L10_pm25 = df['PM2.5 particles (ug/m^3)'].quantile(0.10)

L90_pm1 = df['PM1 particles (ug/m^3)'].quantile(0.90)
L50_pm1 = df['PM1 particles (ug/m^3)'].quantile(0.50)
L10_pm1 = df['PM1 particles (ug/m^3)'].quantile(0.10)

plt.figure(figsize=(40, 20))

# Plot PM values
plt.plot(df['Date Time'], df['PM10 particles (ug/m^3)'], linewidth=3, label=f'PM10 particles (ug/m³) - Max: {max_pm10}', color="r", marker='o')
plt.plot(df['Date Time'], df['PM2.5 particles (ug/m^3)'], linewidth=3, label=f'PM2.5 particles (ug/m³) - Max: {max_pm25}', color="b", marker='o')
plt.plot(df['Date Time'], df['PM1 particles (ug/m^3)'], linewidth=3, label=f'PM1 particles (ug/m³) - Max: {max_pm1}', color="y", marker='o')

# Plot average lines
plt.axhline(y=avg_pm10, color='r', linestyle='--', linewidth=2, label=f'Average PM10: {avg_pm10:.2f}')
plt.axhline(y=avg_pm25, color='b', linestyle='--', linewidth=2, label=f'Average PM2.5: {avg_pm25:.2f}')
plt.axhline(y=avg_pm1, color='y', linestyle='--', linewidth=2, label=f'Average PM1: {avg_pm1:.2f}')

# Ln lines
plt.axhline(y=L90_pm10, color='r', linestyle='-.', linewidth=2, label=f'L90 PM10: {L90_pm10:.2f}')
plt.axhline(y=L50_pm10, color='r', linestyle=':', linewidth=2, label=f'L50 PM10: {L50_pm10:.2f}')
plt.axhline(y=L10_pm10, color='r', linestyle='-', linewidth=2, label=f'L10 PM10: {L10_pm10:.2f}')

plt.axhline(y=L90_pm25, color='b', linestyle='-.', linewidth=2, label=f'L90 PM2.5: {L90_pm25:.2f}')
plt.axhline(y=L50_pm25, color='b', linestyle=':', linewidth=2, label=f'L50 PM2.5: {L50_pm25:.2f}')
plt.axhline(y=L10_pm25, color='b', linestyle='-', linewidth=2, label=f'L10 PM2.5: {L10_pm25:.2f}')

plt.axhline(y=L90_pm1, color='y', linestyle='-.', linewidth=2, label=f'L90 PM1: {L90_pm1:.2f}')
plt.axhline(y=L50_pm1, color='y', linestyle=':', linewidth=2, label=f'L50 PM1: {L50_pm1:.2f}')
plt.axhline(y=L10_pm1, color='y', linestyle='-', linewidth=2, label=f'L10 PM1: {L10_pm1:.2f}')

#plt.suptitle('FIGURE 1', fontsize=40, y=1)
plt.title('Test Site Dust Data for 02/08/24', fontsize=30, pad=30)

plt.xlabel('Time', fontsize=30, labelpad = 30)
plt.ylabel('PM (ug/m³)', fontsize=30, labelpad = 30)
plt.legend(fontsize=25, loc='upper right', bbox_to_anchor=(1.2, 1))

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

plt.xlim(df['Date Time'].min(), df['Date Time'].min() + pd.Timedelta(days=1))
plt.ylim(0, df[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max() + 15)

hour_locator = mdates.HourLocator(interval=1)
plt.gca().xaxis.set_major_locator(hour_locator)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.gca().yaxis.set_major_locator(plt.MultipleLocator(20))
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(2))

plt.tight_layout()
plt.show()

# %% [markdown]
# # Test Site - 02/08/24:

# %%
file_path = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4573_1722639792113 - Test Site.xlsx'
df = pd.read_excel(file_path, sheet_name='Data_HIRE4573_1722639792113', engine='openpyxl')

# max PM values
max_pm10 = df['PM10 particles (ug/m^3)'].max()
max_pm25 = df['PM2.5 particles (ug/m^3)'].max()
max_pm1 = df['PM1 particles (ug/m^3)'].max()

# average PM values
avg_pm10 = df['PM10 particles (ug/m^3)'].mean()
avg_pm25 = df['PM2.5 particles (ug/m^3)'].mean()
avg_pm1 = df['PM1 particles (ug/m^3)'].mean()

plt.figure(figsize=(40, 20))

plt.plot(df['Date Time'], df['PM10 particles (ug/m^3)'], linewidth=3, label=f'PM10 particles - Max: {max_pm10}', color="r", marker='o')
plt.plot(df['Date Time'], df['PM2.5 particles (ug/m^3)'], linewidth=3, label=f'PM2.5 particles - Max: {max_pm25}', color="b", marker='o')
plt.plot(df['Date Time'], df['PM1 particles (ug/m^3)'], linewidth=3, label=f'PM1 particles - Max: {max_pm1}', color="y", marker='o')

# average lines
plt.axhline(y=avg_pm10, color='r', linestyle='--', linewidth=2, label=f'Average PM10: {avg_pm10:.2f}')
plt.axhline(y=avg_pm25, color='b', linestyle='--', linewidth=2, label=f'Average PM2.5: {avg_pm25:.2f}')
plt.axhline(y=avg_pm1, color='y', linestyle='--', linewidth=2, label=f'Average PM1: {avg_pm1:.2f}')

plt.suptitle('FIGURE 1', fontweight='bold', fontsize=40, x=0.52, y=0.999) # y=0.98 for export , y=0.999 otherwise
plt.title('Test Site Dust Data for 02/08/24', fontsize=30, pad=30)

plt.xlabel('Time (h)', fontsize=30, labelpad = 30)
plt.ylabel('PM (μg/m³)', fontsize=30, labelpad = 30)
plt.legend(fontsize=30)

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

plt.xlim(df['Date Time'].min(), df['Date Time'].min() + pd.Timedelta(days=1))
plt.ylim(0, df[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max() + 15)

hour_locator = mdates.HourLocator(interval=2)
plt.gca().xaxis.set_major_locator(hour_locator)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.gca().yaxis.set_major_locator(plt.MultipleLocator(20))
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(5))

#plt.savefig('/Users/ahmad/Pictures/NERC/Figures/Fig1', dpi=300)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Control Site - 02/08/24:

# %%
file_path = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4693_1722639792119 - Control Site.xlsx'

# Using openpyxl engine
df = pd.read_excel(file_path, sheet_name='Data_HIRE4693_1722639792119', engine='openpyxl')

plt.figure(figsize=(40, 20))

# max PM values
max_pm10 = df['PM10 particles (ug/m^3)'].max()
max_pm25 = df['PM2.5 particles (ug/m^3)'].max()
max_pm1 = df['PM1 particles (ug/m^3)'].max()

# average PM values
avg_pm10 = df['PM10 particles (ug/m^3)'].mean()
avg_pm25 = df['PM2.5 particles (ug/m^3)'].mean()
avg_pm1 = df['PM1 particles (ug/m^3)'].mean()

plt.plot(df['Date Time'], df['PM10 particles (ug/m^3)'], linewidth = 3, label=f'PM10 particles - Max: {max_pm10}', color="r", marker='o')
plt.plot(df['Date Time'], df['PM2.5 particles (ug/m^3)'], linewidth = 3, label=f'PM2.5 particles - Max: {max_pm25}', color="b", marker='o')
plt.plot(df['Date Time'], df['PM1 particles (ug/m^3)'], linewidth = 3, label=f'PM1 particles - Max: {max_pm1}', color="y", marker='o')

# average lines
plt.axhline(y=avg_pm10, color='r', linestyle='--', linewidth=2, label=f'Average PM10: {avg_pm10:.2f}')
plt.axhline(y=avg_pm25, color='b', linestyle='--', linewidth=2, label=f'Average PM2.5: {avg_pm25:.2f}')
plt.axhline(y=avg_pm1, color='y', linestyle='--', linewidth=2, label=f'Average PM1: {avg_pm1:.2f}')

plt.suptitle('FIGURE 2', fontweight='bold', fontsize=40, x=0.52, y=0.99) #y = 0.99 for export
plt.title('Control Site Dust Data for 02/08/24', fontsize=30, pad = 30)
plt.xlabel('Time (h)', fontsize=30, labelpad = 30)
plt.ylabel('PM (μg/m³)', fontsize=30, labelpad = 30)
plt.legend(fontsize=30)
#plt.grid(True)

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

plt.xlim(df['Date Time'].min(), df['Date Time'].min() + pd.Timedelta(days=1))
plt.ylim(0, df[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max() + 15)

hour_locator = mdates.HourLocator(interval = 2)
plt.gca().xaxis.set_major_locator(hour_locator)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.gca().yaxis.set_major_locator(plt.MultipleLocator(10))
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(2))

plt.tight_layout()

#plt.savefig('/Users/ahmad/Pictures/NERC/Figures/Figure_2', dpi=300)

plt.show()

#print(df)

# %% [markdown]
# # Test & Control Site comparision - sidewards:

# %%
# import data
file_path_1 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4573_1722639792113 - Test Site.xlsx'
df1 = pd.read_excel(file_path_1, sheet_name='Data_HIRE4573_1722639792113', engine='openpyxl')

file_path_2 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4693_1722639792119 - Control Site.xlsx'
df2 = pd.read_excel(file_path_2, sheet_name='Data_HIRE4693_1722639792119', engine='openpyxl')

# max PM values for control site
max_pm10_control = df2['PM10 particles (ug/m^3)'].max()
max_pm25_control = df2['PM2.5 particles (ug/m^3)'].max()
max_pm1_control = df2['PM1 particles (ug/m^3)'].max()

# max PM values for test site
max_pm10_test = df1['PM10 particles (ug/m^3)'].max()
max_pm25_test = df1['PM2.5 particles (ug/m^3)'].max()
max_pm1_test = df1['PM1 particles (ug/m^3)'].max()

# average values for the control site
avg_pm10_control = df2['PM10 particles (ug/m^3)'].mean()
avg_pm25_control = df2['PM2.5 particles (ug/m^3)'].mean()
avg_pm1_control = df2['PM1 particles (ug/m^3)'].mean()

# average values for the test site
avg_pm10_test = df1['PM10 particles (ug/m^3)'].mean()
avg_pm25_test = df1['PM2.5 particles (ug/m^3)'].mean()
avg_pm1_test = df1['PM1 particles (ug/m^3)'].mean()

# subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(40, 20))

# plot test site data
ax1.plot(df1['Date Time'], df1['PM10 particles (ug/m^3)'], linewidth=3, label=f'PM10 particles - Max: {max_pm10_test}', color="r", marker='o')
ax1.plot(df1['Date Time'], df1['PM2.5 particles (ug/m^3)'], linewidth=3, label=f'PM2.5 particles - Max: {max_pm25_test}', color="b", marker='o')
ax1.plot(df1['Date Time'], df1['PM1 particles (ug/m^3)'], linewidth=3, label=f'PM1 particles - Max: {max_pm1_test}', color="y", marker='o')

# average line test site
ax1.axhline(y=avg_pm10_test, color='r', linestyle='--', linewidth=2, label=f'Average PM10: {avg_pm10_test:.2f}')
ax1.axhline(y=avg_pm25_test, color='b', linestyle='--', linewidth=2, label=f'Average PM2.5: {avg_pm25_test:.2f}')
ax1.axhline(y=avg_pm1_test, color='y', linestyle='--', linewidth=2, label=f'Average PM1: {avg_pm1_test:.2f}')
ax1.set_title('Test Site - 02/08/24', fontsize=30, pad = 30)
ax1.set_xlabel('Time (h)', fontsize=30, labelpad = 15)
ax1.set_ylabel('PM ($μg/m^{3}$)', fontsize=30, labelpad = 15)
ax1.legend(fontsize=20)

ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.set_xlim(df1['Date Time'].min(), df1['Date Time'].min() + pd.Timedelta(days=1))
ax1.set_ylim(0, df1[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max() + 15)

hour_locator = mdates.HourLocator(interval=2)
ax1.xaxis.set_major_locator(hour_locator)
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

ax1.yaxis.set_major_locator(plt.MultipleLocator(20))
ax1.yaxis.set_minor_locator(plt.MultipleLocator(5))

# plot control site data
ax2.plot(df2['Date Time'], df2['PM10 particles (ug/m^3)'], linewidth=3, label=f'PM10 particles - Max: {max_pm10_control}', color="r", marker='o')
ax2.plot(df2['Date Time'], df2['PM2.5 particles (ug/m^3)'], linewidth=3, label=f'PM2.5 particles - Max: {max_pm25_control}', color="b", marker='o')
ax2.plot(df2['Date Time'], df2['PM1 particles (ug/m^3)'], linewidth=3, label=f'PM1 particles - Max: {max_pm1_control}', color="y", marker='o')

# average line control site
ax2.axhline(y=avg_pm10_control, color='r', linestyle='--', linewidth=2, label=f'Average PM10: {avg_pm10_control:.2f}')
ax2.axhline(y=avg_pm25_control, color='b', linestyle='--', linewidth=2, label=f'Average PM2.5: {avg_pm25_control:.2f}')
ax2.axhline(y=avg_pm1_control, color='y', linestyle='--', linewidth=2, label=f'Average PM1: {avg_pm1_control:.2f}')

ax2.set_title('Control Site - 02/08/24', fontsize=30, pad = 30)
ax2.set_xlabel('Time (h)', fontsize=30, labelpad = 15)
ax2.set_ylabel('PM ($μg/m^{3}$)', fontsize=30, labelpad = 15)
ax2.legend(fontsize=20)

ax2.tick_params(axis='both', which='major', labelsize=20)
ax2.set_xlim(df2['Date Time'].min(), df2['Date Time'].min() + pd.Timedelta(days=1))
ax2.set_ylim(0, df1[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max() + 15)

ax2.xaxis.set_major_locator(hour_locator)
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

ax2.yaxis.set_major_locator(plt.MultipleLocator(20))
ax2.yaxis.set_minor_locator(plt.MultipleLocator(5))

plt.suptitle('FIGURE 3', fontweight='bold', fontsize=40, y=0.99) #y = 0.98 for export, 0.99 otherwise

# plt.savefig('/Users/ahmad/Pictures/NERC/Figures/Figure_3', dpi=300)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Test Site & Control Site comparision - stacked:

# %%
file_path_1 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4573_1722639792113 - Test Site.xlsx'
df1 = pd.read_excel(file_path_1, sheet_name='Data_HIRE4573_1722639792113', engine='openpyxl')

file_path_2 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4693_1722639792119 - Control Site.xlsx'
df2 = pd.read_excel(file_path_2, sheet_name='Data_HIRE4693_1722639792119', engine='openpyxl')

# max PM values for control site
max_pm10_control = df2['PM10 particles (ug/m^3)'].max()
max_pm25_control = df2['PM2.5 particles (ug/m^3)'].max()
max_pm1_control = df2['PM1 particles (ug/m^3)'].max()

# max PM values for test site
max_pm10_test = df1['PM10 particles (ug/m^3)'].max()
max_pm25_test = df1['PM2.5 particles (ug/m^3)'].max()
max_pm1_test = df1['PM1 particles (ug/m^3)'].max()

# Calculate average values for the test site
avg_pm10_test = df1['PM10 particles (ug/m^3)'].mean()
avg_pm25_test = df1['PM2.5 particles (ug/m^3)'].mean()
avg_pm1_test = df1['PM1 particles (ug/m^3)'].mean()

# Calculate average values for the control site
avg_pm10_control = df2['PM10 particles (ug/m^3)'].mean()
avg_pm25_control = df2['PM2.5 particles (ug/m^3)'].mean()
avg_pm1_control = df2['PM1 particles (ug/m^3)'].mean()

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 9))

# plot test site data
ax1.plot(df1['Date Time'], df1['PM10 particles (ug/m^3)'], linewidth=1, label=f'PM10 particles - Max: {max_pm10_test}', color="r")
ax1.plot(df1['Date Time'], df1['PM2.5 particles (ug/m^3)'], linewidth=1, label=f'PM2.5 particles - Max: {max_pm25_test}', color="b")
ax1.plot(df1['Date Time'], df1['PM1 particles (ug/m^3)'], linewidth=1, label=f'PM1 particles - Max: {max_pm1_test}', color="y")

#Average line for test site
ax1.axhline(y=avg_pm10_test, color='r', linestyle='--', linewidth=1, label=f'Avg PM10: {avg_pm10_test:.2f}')
ax1.axhline(y=avg_pm25_test, color='b', linestyle='--', linewidth=1, label=f'Avg PM2.5: {avg_pm25_test:.2f}')
ax1.axhline(y=avg_pm1_test, color='y', linestyle='--', linewidth=1, label=f'Avg PM1: {avg_pm1_test:.2f}')

ax1.set_title('Test Site - 02/08/24', fontsize=10)
ax1.set_xlabel('Time (h)', fontsize=10)
ax1.set_ylabel('PM ($μg/m^3$)', fontsize=10)
ax1.legend(fontsize=10)

ax1.tick_params(axis='both', which='major', labelsize=10)
ax1.set_xlim(df1['Date Time'].min(), df1['Date Time'].min() + pd.Timedelta(days=1))
ax1.set_ylim(0, df1[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max() + 15)

hour_locator = mdates.HourLocator(interval=1)
ax1.xaxis.set_major_locator(hour_locator)
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

ax1.yaxis.set_major_locator(plt.MultipleLocator(20))
ax1.yaxis.set_minor_locator(plt.MultipleLocator(5000))

# plot control site data
ax2.plot(df2['Date Time'], df2['PM10 particles (ug/m^3)'], linewidth=1, label=f'PM10 particles - Max: {max_pm10_control}', color="r")
ax2.plot(df2['Date Time'], df2['PM2.5 particles (ug/m^3)'], linewidth=1, label=f'PM2.5 particles - Max: {max_pm25_control}', color="b")
ax2.plot(df2['Date Time'], df2['PM1 particles (ug/m^3)'], linewidth=1, label=f'PM1 particles - Max: {max_pm1_control}', color="y")

# Average line for control site
ax2.axhline(y=avg_pm10_control, color='r', linestyle='--', linewidth=1, label=f'Avg PM10: {avg_pm10_control:.2f}')
ax2.axhline(y=avg_pm25_control, color='b', linestyle='--', linewidth=1, label=f'Avg PM2.5: {avg_pm25_control:.2f}')
ax2.axhline(y=avg_pm1_control, color='y', linestyle='--', linewidth=1, label=f'Avg PM1: {avg_pm1_control:.2f}')
ax2.set_title('Control Site - 02/08/24', fontsize=10)

ax2.set_xlabel('Time (h)', fontsize=10)
ax2.set_ylabel('PM ($μg/m^3$)', fontsize=10)
ax2.legend(fontsize=10)

ax2.tick_params(axis='both', which='major', labelsize=10)
ax2.set_xlim(df2['Date Time'].min(), df2['Date Time'].min() + pd.Timedelta(days=1))
ax2.set_ylim(0, df1[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max() + 15)

ax2.xaxis.set_major_locator(hour_locator)
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

ax2.yaxis.set_major_locator(plt.MultipleLocator(20))
ax2.yaxis.set_minor_locator(plt.MultipleLocator(100000))

plt.suptitle('FIGURE 4', fontweight='bold', fontsize=15, x=0.515, y=0.98)

# plt.savefig('/Users/ahmad/Pictures/NERC/Figures/Figure_4', dpi=300)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparision between control / test site:

# %%
file_path_1 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4573_1722639792113 - Test Site.xlsx'
df1 = pd.read_excel(file_path_1, sheet_name='Data_HIRE4573_1722639792113', engine='openpyxl')

file_path_2 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4693_1722639792119 - Control Site.xlsx'
df2 = pd.read_excel(file_path_2, sheet_name='Data_HIRE4693_1722639792119', engine='openpyxl')

fig, ax = plt.subplots(figsize=(15, 9))

ax.plot(df1['Date Time'], df1['PM10 particles (ug/m^3)'], linewidth=1, label='Test Site PM10 particles', color="r")
ax.plot(df1['Date Time'], df1['PM2.5 particles (ug/m^3)'], linewidth=1, label='Test Site PM2.5 particles', color="b")
ax.plot(df1['Date Time'], df1['PM1 particles (ug/m^3)'], linewidth=1, label='Test Site PM1 particles', color="y")

ax.plot(df2['Date Time'], df2['PM10 particles (ug/m^3)'], linewidth=1, linestyle='--', label='Control Site PM10 particles', color="r")
ax.plot(df2['Date Time'], df2['PM2.5 particles (ug/m^3)'], linewidth=1, linestyle='--', label='Control Site PM2.5 particles', color="b")
ax.plot(df2['Date Time'], df2['PM1 particles (ug/m^3)'], linewidth=1, linestyle='--', label='Control Site PM1 particles', color="y")

ax.set_title('Test vs Control Site - 02/08/24', fontsize=14)
ax.set_xlabel('Time (h)', fontsize=12)
ax.set_ylabel('PM ($μg/m^3$)', fontsize=12)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.set_xlim(df1['Date Time'].min(), df1['Date Time'].min() + pd.Timedelta(days=1))
ax.set_ylim(0, max(df1[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max(),
                  df2[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max()) + 15)

hour_locator = mdates.HourLocator(interval=1)
ax.xaxis.set_major_locator(hour_locator)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

ax.yaxis.set_major_locator(plt.MultipleLocator(20))
ax.yaxis.set_minor_locator(plt.MultipleLocator(5))

ax.legend(fontsize=10)

plt.suptitle('FIGURE 5', fontweight='bold', fontsize=15, x=0.52, y=0.989)

# plt.savefig('/Users/ahmad/Pictures/NERC/Figures/Figure_5', dpi=300)

plt.tight_layout()
plt.show()

#cclean up - graph looks messy

# %% [markdown]
# # PM10 Comparision:

# %%
file_path_1 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4573_1722639792113 - Test Site.xlsx'
df1 = pd.read_excel(file_path_1, sheet_name='Data_HIRE4573_1722639792113', engine='openpyxl')

file_path_2 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4693_1722639792119 - Control Site.xlsx'
df2 = pd.read_excel(file_path_2, sheet_name='Data_HIRE4693_1722639792119', engine='openpyxl')

fig, ax = plt.subplots(figsize=(15, 9))

# max PM values
max_pm10_test = df1['PM10 particles (ug/m^3)'].max()
max_pm10_control = df2['PM10 particles (ug/m^3)'].max()

ax.plot(df1['Date Time'], df1['PM10 particles (ug/m^3)'], linewidth=1, label=f'Test Site PM10 particles - Max: {max_pm10_test}', color="r")

ax.plot(df2['Date Time'], df2['PM10 particles (ug/m^3)'], linewidth=1, label=f'Control Site PM10 particles - Max: {max_pm10_control}', color="b")

ax.set_title('PM10 Test vs Control Site - 02/08/24', fontsize=14)
ax.set_xlabel('Time (h)', fontsize=12)
ax.set_ylabel('PM ($μg/m^3$)', fontsize=12)

# average PM value
avg_pm10_test = df1['PM10 particles (ug/m^3)'].mean()
avg_pm10_control = df2['PM10 particles (ug/m^3)'].mean()

# average lines
plt.axhline(y=avg_pm10_test, color='r', linestyle='--', linewidth=1, label=f'Average PM10 Test Site: {avg_pm10_test:.2f}')
plt.axhline(y=avg_pm10_control, color='b', linestyle='--', linewidth=1, label=f'Average PM10 Control Site: {avg_pm10_control:.2f}')

ax.tick_params(axis='both', which='major', labelsize=10)
ax.set_xlim(df1['Date Time'].min(), df1['Date Time'].min() + pd.Timedelta(days=1))
ax.set_ylim(0, max(df1[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max(),
                  df2[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max()) + 15)

hour_locator = mdates.HourLocator(interval=1)
ax.xaxis.set_major_locator(hour_locator)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

ax.yaxis.set_major_locator(plt.MultipleLocator(20))
ax.yaxis.set_minor_locator(plt.MultipleLocator(5))

ax.legend(fontsize=10)

plt.suptitle('FIGURE 6',  fontweight='bold', fontsize=15, x=0.52, y=0.989) #y = 0.9

# plt.savefig('/Users/ahmad/Pictures/NERC/Figures/Figure_6', dpi=300)

plt.tight_layout()
plt.show()

# %% [markdown]
# # PM2.5 Comparision:

# %%
file_path_1 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4573_1722639792113 - Test Site.xlsx'
df1 = pd.read_excel(file_path_1, sheet_name='Data_HIRE4573_1722639792113', engine='openpyxl')

file_path_2 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4693_1722639792119 - Control Site.xlsx'
df2 = pd.read_excel(file_path_2, sheet_name='Data_HIRE4693_1722639792119', engine='openpyxl')

fig, ax = plt.subplots(figsize=(15, 9))

# max PM values
max_pm25_test = df1['PM2.5 particles (ug/m^3)'].max()
max_pm25_control = df2['PM2.5 particles (ug/m^3)'].max()

ax.plot(df1['Date Time'], df1['PM2.5 particles (ug/m^3)'], linewidth=1, label=f'Test Site PM2.5 particles - Max: {max_pm25_test}', color="r")

ax.plot(df2['Date Time'], df2['PM2.5 particles (ug/m^3)'], linewidth=1, label=f'Control Site PM2.5 particles - Max: {max_pm25_control}', color="b")

ax.set_title('Dust Data Comparison for Test Site and Control Site on 02/08/24', fontsize=14)
ax.set_xlabel('Time', fontsize=12)
ax.set_ylabel('PM (ug/m^3)', fontsize=12)

# average PM value
avg_pm25_test = df1['PM2.5 particles (ug/m^3)'].mean()
avg_pm25_control = df2['PM2.5 particles (ug/m^3)'].mean()

# average lines
plt.axhline(y=avg_pm25_test, color='r', linestyle='--', linewidth=1, label=f'Average PM2.5 Test Site: {avg_pm25_test:.2f}')
plt.axhline(y=avg_pm25_control, color='b', linestyle='--', linewidth=1, label=f'Average PM2.5 Control Site: {avg_pm25_control:.2f}')

ax.set_title('PM2.5 Test vs Control Site - 02/08/24', fontsize=14)
ax.set_xlabel('Time (h)', fontsize=12)
ax.set_ylabel('PM ($μg/m^3$)', fontsize=12)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.set_xlim(df1['Date Time'].min(), df1['Date Time'].min() + pd.Timedelta(days=1))
ax.set_ylim(0, max(df1[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max(),
                  df2[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max()) + 15)

hour_locator = mdates.HourLocator(interval=1)
ax.xaxis.set_major_locator(hour_locator)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

ax.yaxis.set_major_locator(plt.MultipleLocator(20))
ax.yaxis.set_minor_locator(plt.MultipleLocator(5))

ax.legend(fontsize=10)

plt.suptitle('FIGURE 7', fontweight='bold', fontsize=15, x=0.52, y=0.989)

# plt.savefig('/Users/ahmad/Pictures/NERC/Figures/Figure_7', dpi=300)

plt.tight_layout()
plt.show()

# %% [markdown]
# # PM1 Comparision:

# %%
file_path_1 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4573_1722639792113 - Test Site.xlsx'
df1 = pd.read_excel(file_path_1, sheet_name='Data_HIRE4573_1722639792113', engine='openpyxl')

file_path_2 = '/Users/ahmad/Documents/NERC Internship/Excel/Actual Data/Dust_perday/2:8:24/Data_HIRE4693_1722639792119 - Control Site.xlsx'
df2 = pd.read_excel(file_path_2, sheet_name='Data_HIRE4693_1722639792119', engine='openpyxl')

fig, ax = plt.subplots(figsize=(15, 9))

# max PM values
max_pm1_test = df1['PM1 particles (ug/m^3)'].max()
max_pm1_control = df2['PM1 particles (ug/m^3)'].max()

ax.plot(df1['Date Time'], df1['PM1 particles (ug/m^3)'], linewidth=1, label=f'Test Site PM1 particles - Max: {max_pm1_test}', color="r")

ax.plot(df2['Date Time'], df2['PM1 particles (ug/m^3)'], linewidth=1, label=f'Control Site PM1 particles - Max: {max_pm1_control}', color="b")

ax.set_title('Dust Data Comparison for Test Site and Control Site on 02/08/24', fontsize=14)
ax.set_xlabel('Time', fontsize=12)
ax.set_ylabel('PM (ug/m^3)', fontsize=12)

# average PM value
avg_pm1_test = df1['PM1 particles (ug/m^3)'].mean()
avg_pm1_control = df2['PM1 particles (ug/m^3)'].mean()

# average lines
plt.axhline(y=avg_pm1_test, color='r', linestyle='--', linewidth=1, label=f'Average PM1 Test Site: {avg_pm1_test:.2f}')
plt.axhline(y=avg_pm1_control, color='b', linestyle='--', linewidth=1, label=f'Average PM1 Control Site: {avg_pm1_control:.2f}')

ax.set_title('PM1 Test vs Control Site - 02/08/24', fontsize=14)
ax.set_xlabel('Time (h)', fontsize=12)
ax.set_ylabel('PM ($μg/m^3$)', fontsize=12)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.set_xlim(df1['Date Time'].min(), df1['Date Time'].min() + pd.Timedelta(days=1))
ax.set_ylim(0, max(df1[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max(),
                  df2[['PM10 particles (ug/m^3)', 'PM2.5 particles (ug/m^3)', 'PM1 particles (ug/m^3)']].max().max()) + 15)

hour_locator = mdates.HourLocator(interval=1)
ax.xaxis.set_major_locator(hour_locator)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

ax.yaxis.set_major_locator(plt.MultipleLocator(20))
ax.yaxis.set_minor_locator(plt.MultipleLocator(5))

ax.legend(fontsize=10)

plt.suptitle('FIGURE 8', fontweight='bold', fontsize=15, x=0.52, y=0.989)

#  plt.savefig('/Users/ahmad/Pictures/NERC/Figures/Figure_8', dpi=300)

plt.tight_layout()
plt.show()
